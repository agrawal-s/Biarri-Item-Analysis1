# %% [markdown]
# ### This notebook provides a rough idea of how to combine the similar items in the transactions into unified value. This is to be done in order to reduce the item size.
#
# #### Note: So far, i have managed to reduce 5000 different items to approx 3300 items which is considerable difference when it comes to computation costs. This number can be increased / decreased by modifying the hyperparameters like similarity threshold and jaccard token size.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the data
df = pd.read_excel('online_merged.xlsx', sheet_name='merged')

# %%
# Stripping white spaces from the item description column
df['Description'] = df['Description'].str.strip()

# %%
# Defining functions for finding Jaccard similarities

def Intersection(lst1, lst2): 
    return list(set(lst1).intersection(lst2))

def Union(lst1, lst2): 
    final_list = list(set(lst1) | set(lst2)) 
    return final_list 

def tokens(word,token_size = 3):
    return [word[i:i+token_size] for i in range(0,len(word)-token_size + 1)]

def find_jaccard(word1, word2, token_size = 3):
    tokens1 = tokens(word1, token_size)
    tokens2 = tokens(word2, token_size)
    return (len(Intersection(tokens1, tokens2))/len(Union(tokens1, tokens2)))

# %%
# Unique item description list

unq_desc = df.Description.unique()

# %%
# Sample list of items to show the working
list1 = ['CHOCOLATE BOX RIBBONS',
'DINOSAUR LUNCH BOX WITH CUTLERY',
'DINOSAUR LUNCHBOX WITH CUTLERY',
'EASTER BUNNY WITH BASKET ON BACK',
'EASTER BUNNY WREATH',
'ELEPHANT TOY WITH BLUE T-SHIRT',
'HEART BUTTONS JEWELLERY BOX',
'LUNCH BOX WITH CUTLERY FAIRY CAKES',
'LUNCH BOX WITH CUTLERY RETROSPOT',
'LUNCHBOX WITH CUTLERY FAIRY CAKES',
'LUNCHBOX WITH CUTLERY RETROSPOT',
'NEW BAROQUE IVORY CUSHION COVER',
'SKULL LUNCH BOX WITH CUTLERY',
'SKULL LUNCHBOX WITH CUTLERY',
'STRAWBERRY LUNCH BOX WITH CUTLERY',
'STRAWBERRY LUNCHBOX WITH CUTLERY',
'UTILTY CABINET WITH HOOKS']
list1
# Out:
# ['CHOCOLATE BOX RIBBONS',
#  'DINOSAUR LUNCH BOX WITH CUTLERY',
#  'DINOSAUR LUNCHBOX WITH CUTLERY',
#  'EASTER BUNNY WITH BASKET ON BACK',
#  'EASTER BUNNY WREATH',
#  'ELEPHANT TOY WITH BLUE T-SHIRT',
#  'HEART BUTTONS JEWELLERY BOX',
#  'LUNCH BOX WITH CUTLERY FAIRY CAKES',
#  'LUNCH BOX WITH CUTLERY RETROSPOT',
#  'LUNCHBOX WITH CUTLERY FAIRY CAKES',
#  'LUNCHBOX WITH CUTLERY RETROSPOT',
#  'NEW BAROQUE IVORY CUSHION COVER',
#  'SKULL LUNCH BOX WITH CUTLERY',
#  'SKULL LUNCHBOX WITH CUTLERY',
#  'STRAWBERRY LUNCH BOX WITH CUTLERY',
#  'STRAWBERRY LUNCHBOX WITH CUTLERY',
#  'UTILTY CABINET WITH HOOKS']

# %%
# Grouping the similar items based on unique item description list to create a lookup result

from difflib import SequenceMatcher as sm

combined_list = list1 # Use unq_desc to get complete list of combinations from txns.
result = list()
result_group = list()
usedElements = list()
skip = False

for firstName in combined_list:
    skip = False

    for x in usedElements:
        if x == firstName:
            skip = True
    if skip == True:
        continue

    for secondName in combined_list:

        #if(sm(None, firstName, secondName).ratio() >= 0.70):            
        if(find_jaccard(firstName, secondName) >= 0.50):            

            result_group.append(secondName)
            usedElements.append(secondName)
        else:
            pass

    result.append(result_group[:])
    del result_group[:]

for value in result:
    print(value)
# Out:
# ['CHOCOLATE BOX RIBBONS']
# ['DINOSAUR LUNCH BOX WITH CUTLERY', 'DINOSAUR LUNCHBOX WITH CUTLERY', 'LUNCH BOX WITH CUTLERY FAIRY CAKES', 'LUNCH BOX WITH CUTLERY RETROSPOT', 'SKULL LUNCH BOX WITH CUTLERY', 'SKULL LUNCHBOX WITH CUTLERY', 'STRAWBERRY LUNCH BOX WITH CUTLERY']
# ['EASTER BUNNY WITH BASKET ON BACK']
# ['EASTER BUNNY WREATH']
# ['ELEPHANT TOY WITH BLUE T-SHIRT']
# ['HEART BUTTONS JEWELLERY BOX']
# ['LUNCH BOX WITH CUTLERY FAIRY CAKES', 'LUNCHBOX WITH CUTLERY FAIRY CAKES', 'LUNCHBOX WITH CUTLERY RETROSPOT', 'SKULL LUNCHBOX WITH CUTLERY', 'STRAWBERRY LUNCHBOX WITH CUTLERY']
# ['NEW BAROQUE IVORY CUSHION COVER']
# ['UTILTY CABINET WITH HOOKS']

# %%
df1 = df
df1.head()
# Out:
#    Invoice StockCode                      Description  Quantity  \
# 0   493414     21844                   RETRO SPOT MUG        36
# 1   493414     21533        RETRO SPOT LARGE MILK JUG        12
# 2   493414     37508  NEW ENGLAND CERAMIC CAKE SERVER         2
# 3   493414    35001G             HAND OPEN SHAPE GOLD         2
# 4   493414     21527    RETRO SPOT TRADITIONAL TEAPOT        12
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-01-04 10:28:00   2.55        14590  United Kingdom
# 1 2010-01-04 10:28:00   4.25        14590  United Kingdom
# 2 2010-01-04 10:28:00   2.55        14590  United Kingdom
# 3 2010-01-04 10:28:00   4.25        14590  United Kingdom
# 4 2010-01-04 10:28:00   6.95        14590  United Kingdom

# %%
df1_price = df1[(df1[['Price','Quantity']] > 0).all(axis=1)]
df1.describe()
# Out:
#              Invoice       Quantity          Price    Customer ID
# count  770692.000000  770692.000000  770692.000000  770692.000000
# mean   539271.351953      13.286099       2.993243   15327.973197
# std     25509.968171     146.100973      11.160934    1696.651545
# min    493414.000000       1.000000       0.001000   12346.000000
# 25%    517964.000000       2.000000       1.250000   13975.000000
# 50%    537868.000000       5.000000       1.950000   15260.000000
# 75%    562460.000000      12.000000       3.750000   16800.000000
# max    581587.000000   80995.000000    8142.750000   18287.000000

# %%
# Creating a sample transaction dataframe from origional DF for testing purposes.

#np.random.seed(123)
#sample_desc = np.random.choice(unq_desc, size = 7)

sample_txn = df1[df1['Description'].isin(list1)]

sample_txn = sample_txn.sample(n = 100)

len(sample_txn.Invoice.unique())

sample_txn.groupby(['StockCode']).count()

sample_txn['TotalPrice'] = sample_txn['Price']*sample_txn['Quantity']

sample_txn

#basket = (sample_txn.groupby(['Invoice', 'Description'])['TotalPrice'] 
#          .sum().unstack().reset_index().fillna(0) 
#          .set_index('Invoice')) 
#basket
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 36399    498395     21559    STRAWBERRY LUNCHBOX WITH CUTLERY       240
# 323728   532636     21561     DINOSAUR LUNCH BOX WITH CUTLERY         6
# 353277   535662     21559   STRAWBERRY LUNCH BOX WITH CUTLERY         1
# 437977   544824     22352    LUNCH BOX WITH CUTLERY RETROSPOT         6
# 46346    499772     21559    STRAWBERRY LUNCHBOX WITH CUTLERY         2
# ...         ...       ...                                 ...       ...
# 450814   546392     21561     DINOSAUR LUNCH BOX WITH CUTLERY         1
# 119340   508654     22353  LUNCH BOX WITH CUTLERY FAIRY CAKES         6
# 160772   513809     21559   STRAWBERRY LUNCH BOX WITH CUTLERY         6
# 585815   563360     21558        SKULL LUNCH BOX WITH CUTLERY         4
# 101228   506278     22352    LUNCH BOX WITH CUTLERY RETROSPOT         6
#
#                InvoiceDate  Price  Customer ID         Country  TotalPrice
# 36399  2010-02-18 15:13:00   2.10        14646     Netherlands      504.00
# 323728 2010-11-12 15:46:00   2.55        12635         Germany       15.30
# 353277 2010-11-28 11:37:00   2.55        16782  United Kingdom        2.55
# 437977 2011-02-24 09:32:00   2.55        17139  United Kingdom       15.30
# 46346  2010-03-02 13:36:00   2.55        16960  United Kingdom        5.10
# ...                    ...    ...          ...             ...         ...
# 450814 2011-03-11 14:15:00   2.55        14587  United Kingdom        2.55
# 119340 2010-05-17 15:54:00   2.55        15296  United Kingdom       15.30
# 160772 2010-06-29 09:28:00   2.55        12682          France       15.30
# 585815 2011-08-15 15:06:00   2.55        15023  United Kingdom       10.20
# 101228 2010-04-28 15:51:00   2.55        12698         Germany       15.30
#
# [100 rows x 9 columns]

# %%
# Checking the groupped values before unifying the descriptions

sums = sample_txn.groupby(['Description']).sum()
sums
# Out:
#                                      Invoice  Quantity  Price  Customer ID  \
# Description
# CHOCOLATE BOX RIBBONS                6325301        81  15.00       186537
# DINOSAUR LUNCH BOX WITH CUTLERY      6966806        45  33.15       204946
# EASTER BUNNY WITH BASKET ON BACK      547896         2   0.65        17841
# EASTER BUNNY WREATH                  1094135         3   9.90        32317
# ELEPHANT TOY WITH BLUE T-SHIRT        997367         3   7.50        27870
# HEART BUTTONS JEWELLERY BOX           513625         1   7.65        14505
# LUNCH BOX WITH CUTLERY FAIRY CAKES   4616419        48  22.95       135733
# LUNCH BOX WITH CUTLERY RETROSPOT    10138611       100  48.45       282839
# LUNCHBOX WITH CUTLERY FAIRY CAKES     499302         6   2.55        18223
# LUNCHBOX WITH CUTLERY RETROSPOT      1999069        12  10.20        62250
# SKULL LUNCH BOX WITH CUTLERY         5425132        95  25.05       143900
# STRAWBERRY LUNCH BOX WITH CUTLERY   12975387       238  60.30       341026
# STRAWBERRY LUNCHBOX WITH CUTLERY      998167       242   4.65        31606
#
#                                     TotalPrice
# Description
# CHOCOLATE BOX RIBBONS                   101.25
# DINOSAUR LUNCH BOX WITH CUTLERY         114.75
# EASTER BUNNY WITH BASKET ON BACK          1.30
# EASTER BUNNY WREATH                      14.85
# ELEPHANT TOY WITH BLUE T-SHIRT           11.25
# HEART BUTTONS JEWELLERY BOX               7.65
# LUNCH BOX WITH CUTLERY FAIRY CAKES      122.40
# LUNCH BOX WITH CUTLERY RETROSPOT        255.00
# LUNCHBOX WITH CUTLERY FAIRY CAKES        15.30
# LUNCHBOX WITH CUTLERY RETROSPOT          30.60
# SKULL LUNCH BOX WITH CUTLERY            215.25
# STRAWBERRY LUNCH BOX WITH CUTLERY       552.90
# STRAWBERRY LUNCHBOX WITH CUTLERY        509.10

# %%
#unifying the item description using lookup from results

for index, row in sample_txn.iterrows():
    
    for desc_list in result:
            #if col in 
        if(row['Description'] in desc_list):
            print('before conversion:')
            print(row['Description'], ',', desc_list[0])
            sample_txn.at[index,'Description'] =  desc_list[0]
            print('After conversion:')
            print(row['Description'], ',', desc_list[0])
            print('-------------------------------------------------------------------------')
            
            break
            #print('-------------------------------------------------------------------------')
            #print(round(row.sum(),2))
#col_list_full
# Out:
# before conversion:
# STRAWBERRY LUNCHBOX WITH CUTLERY , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# STRAWBERRY LUNCHBOX WITH CUTLERY , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCHBOX WITH CUTLERY , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# STRAWBERRY LUNCHBOX WITH CUTLERY , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# EASTER BUNNY WREATH , EASTER BUNNY WREATH
# After conversion:
# EASTER BUNNY WREATH , EASTER BUNNY WREATH
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# ELEPHANT TOY WITH BLUE T-SHIRT , ELEPHANT TOY WITH BLUE T-SHIRT
# After conversion:
# ELEPHANT TOY WITH BLUE T-SHIRT , ELEPHANT TOY WITH BLUE T-SHIRT
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# HEART BUTTONS JEWELLERY BOX , HEART BUTTONS JEWELLERY BOX
# After conversion:
# HEART BUTTONS JEWELLERY BOX , HEART BUTTONS JEWELLERY BOX
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCHBOX WITH CUTLERY FAIRY CAKES , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# LUNCHBOX WITH CUTLERY FAIRY CAKES , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# After conversion:
# LUNCHBOX WITH CUTLERY RETROSPOT , LUNCH BOX WITH CUTLERY FAIRY CAKES
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# ELEPHANT TOY WITH BLUE T-SHIRT , ELEPHANT TOY WITH BLUE T-SHIRT
# After conversion:
# ELEPHANT TOY WITH BLUE T-SHIRT , ELEPHANT TOY WITH BLUE T-SHIRT
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# After conversion:
# CHOCOLATE BOX RIBBONS , CHOCOLATE BOX RIBBONS
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# EASTER BUNNY WREATH , EASTER BUNNY WREATH
# After conversion:
# EASTER BUNNY WREATH , EASTER BUNNY WREATH
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# EASTER BUNNY WITH BASKET ON BACK , EASTER BUNNY WITH BASKET ON BACK
# After conversion:
# EASTER BUNNY WITH BASKET ON BACK , EASTER BUNNY WITH BASKET ON BACK
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# DINOSAUR LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY FAIRY CAKES , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# STRAWBERRY LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# SKULL LUNCH BOX WITH CUTLERY , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------
# before conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# After conversion:
# LUNCH BOX WITH CUTLERY RETROSPOT , DINOSAUR LUNCH BOX WITH CUTLERY
# -------------------------------------------------------------------------

# %%
# Checking the groupped values after unifying the descriptions

sums = sample_txn.groupby(['Description']).sum()
sums
# Out:
#                                      Invoice  Quantity   Price  Customer ID  \
# Description
# CHOCOLATE BOX RIBBONS                6325301        81   15.00       186537
# DINOSAUR LUNCH BOX WITH CUTLERY     40122355       526  189.90      1108444
# EASTER BUNNY WITH BASKET ON BACK      547896         2    0.65        17841
# EASTER BUNNY WREATH                  1094135         3    9.90        32317
# ELEPHANT TOY WITH BLUE T-SHIRT        997367         3    7.50        27870
# HEART BUTTONS JEWELLERY BOX           513625         1    7.65        14505
# LUNCH BOX WITH CUTLERY FAIRY CAKES   3496538       260   17.40       112079
#
#                                     TotalPrice
# Description
# CHOCOLATE BOX RIBBONS                   101.25
# DINOSAUR LUNCH BOX WITH CUTLERY        1260.30
# EASTER BUNNY WITH BASKET ON BACK          1.30
# EASTER BUNNY WREATH                      14.85
# ELEPHANT TOY WITH BLUE T-SHIRT           11.25
# HEART BUTTONS JEWELLERY BOX               7.65
# LUNCH BOX WITH CUTLERY FAIRY CAKES      555.00

# %%
sums['Description']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Users\shree\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-875b256f58ba> in <module>
# ----> 1 sums['Description']
#
# D:\Users\shree\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# D:\Users\shree\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Description'
