# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("pokemon.csv")

# %%
pkm = df[['attack','defense','hp','sp_attack','sp_defense','speed']]

# %%
pkm
# Out:
#      attack  defense   hp  sp_attack  sp_defense  speed
# 0        49       49   45         65          65     45
# 1        62       63   60         80          80     60
# 2       100      123   80        122         120     80
# 3        52       43   39         60          50     65
# 4        64       58   58         80          65     80
# ..      ...      ...  ...        ...         ...    ...
# 796     101      103   97        107         101     61
# 797     181      131   59         59          31    109
# 798     101       53  223         97          53     43
# 799     107      101   97        127          89     79
# 800      95      115   80        130         115     65
#
# [801 rows x 6 columns]

# %%
corr_matrix = pkm.corr(method = 'pearson')
corr_matrix
# Out:
#               attack   defense        hp  sp_attack  sp_defense     speed
# attack      1.000000  0.468915  0.410616   0.368154    0.265836  0.352703
# defense     0.468915  1.000000  0.242378   0.241882    0.526348  0.007934
# hp          0.410616  0.242378  1.000000   0.365973    0.366971  0.160760
# sp_attack   0.368154  0.241882  0.365973   1.000000    0.511496  0.438981
# sp_defense  0.265836  0.526348  0.366971   0.511496    1.000000  0.225977
# speed       0.352703  0.007934  0.160760   0.438981    0.225977  1.000000

# %%
fig=plt.figure(figsize=(8, 8), dpi= 80, facecolor='w', edgecolor='k')
sns.heatmap(pkm.corr())

# %%
from scipy.stats import pearsonr

# %%
pearsonr(pkm['speed'],pkm['defense'])
# Out:
# (0.007934069032646911, 0.822599793595251)

# %%
pkm[['speed']]
pkm[['defense']]
# Out:
#      defense
# 0         49
# 1         63
# 2        123
# 3         43
# 4         58
# ..       ...
# 796      103
# 797      131
# 798       53
# 799      101
# 800      115
#
# [801 rows x 1 columns]
